# %% [markdown]
# # SAHIL RAJ
#
# #SAVED MODEL NOTEBOOK

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
# Loading the saved model
loaded_model = load_model("mobilenet.h5")

# %%
#Below is the prediction made on validation data for leaf mold disease using mobilenet architecture.

# %%
img_path = "C:\\Users\\Sahil\\Downloads\\Tomatoes\\val\\Tomato___Leaf_Mold\\2ba2d560-919c-48cd-8f98-c4caf8fc37e7___Crnl_L.Mold 8994.JPG"  # Replace with the path to your image
img = image.load_img(img_path, target_size=(224, 224))  # Assuming 224x224 input size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0 
# Displaying the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# predictions
predictions = loaded_model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 491ms/step

# %%
class_index = np.argmax(predictions)
class_labels = ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_mosaic_virus', 'Tomato_Yellow_Leaf_Curl_Virus', 'healthy']  # Replace with your class labels
predicted_class = class_labels[class_index]

print(f"The predicted class is: {predicted_class}")
# Out:
# The predicted class is: Leaf_Mold

# %%
#Now prediction on unseen data

# %%
import matplotlib.pyplot as plt
img_path = "C:\\Users\\Sahil\\Desktop\\UNSEEN.JPG" 
img = image.load_img(img_path, target_size=(224, 224))  
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0 
# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#  predictions
predictions = loaded_model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
class_index = np.argmax(predictions)
class_labels = ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_mosaic_virus', 'Tomato_Yellow_Leaf_Curl_Virus', 'healthy']  # Replace with your class labels
predicted_class = class_labels[class_index]
# Displaying the predicted class label
print(f"The predicted class is: {predicted_class}")
# Out:
# The predicted class is: Bacterial_spot
